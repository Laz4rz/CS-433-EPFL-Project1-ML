# %%
import pandas as pd

# %%
DATAPATH = "data/"
X_TEST = DATAPATH + "x_test.csv"
X_TRAIN = DATAPATH + "x_train.csv"
Y_TRAIN = DATAPATH + "y_train.csv"

# %%
xtest = pd.read_csv(X_TEST)
xtrain = pd.read_csv(X_TRAIN)
ytrain = pd.read_csv(Y_TRAIN)

# %%
xtrain.loc[:, (xtrain.isna().sum() / len(xtrain)) < 0.9].isna().sum(1).plot()
# Out:
# <Axes: >

# %%
xtrain.isna().sum(1).plot()
# Out:
# <Axes: >

# %% [markdown]
# ### % of missing values per column

# %%
(xtrain.isna().sum() / len(xtrain)) - (xtest.isna().sum() / len(xtest))[(xtrain.isna().sum() / len(xtrain)) - (xtest.isna().sum() / len(xtest)) != 0]
# Out:
# ACTIN11_    0.000377
# ACTIN21_    0.000849
# ADANXEV     0.000454
# ADDEPEV2         NaN
# ADDOWN      0.000414
#               ...
# _VEGESUM   -0.001389
# _VEGETEX         NaN
# _VEGLT1          NaN
# _VEGRESP         NaN
# _WT2RAKE         NaN
# Length: 321, dtype: float64

# %%
def plot_missing_percentage(df):
    (df.isna().sum() / len(df)).plot.bar(figsize=(30, 5))

# %%
plot_missing_percentage(xtest)

# %%
plot_missing_percentage(xtrain)

# %%
import seaborn as sns

# %%
corr = xtrain.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
xtrain.dtypes
# Out:
# _STATE        int64
# FMONTH        int64
# IDATE         int64
# IMONTH        int64
# IDAY          int64
#              ...
# _RFSEAT2      int64
# _RFSEAT3      int64
# _FLSHOT6    float64
# _PNEUMO2    float64
# _AIDTST3    float64
# Length: 321, dtype: object
